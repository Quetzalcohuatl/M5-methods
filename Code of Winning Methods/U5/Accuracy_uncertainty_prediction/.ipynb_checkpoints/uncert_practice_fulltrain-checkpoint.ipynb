# %%
############## import
######################################################
import numpy as np
import pandas as pd

# %%
############## data download
######################################################
train_df = pd.read_csv("m5-forecasting-accuracy/sales_train_evaluation.csv")
sample_submission = pd.read_csv("m5-forecasting-accuracy/sample_submission.csv")
cf = pd.read_pickle("weights/weight_size_change_format.pkl")

# %%
product = train_df[['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']].drop_duplicates()
product["store_item_id"] = product["item_id"] + "_" + product["store_id"]

# %%
index_list = ["Total_X"]
state = list(pd.get_dummies(product.state_id.astype(str),drop_first=False).astype('int8').columns)
store = list(pd.get_dummies(product.store_id.astype(str),drop_first=False).astype('int8').columns)
cat = list(pd.get_dummies(product.cat_id.astype(str),drop_first=False).astype('int8').columns)
dept = list(pd.get_dummies(product.dept_id.astype(str),drop_first=False).astype('int8').columns)
state_cat = list(pd.get_dummies(product.state_id.astype(str) + "_" + product.cat_id.astype(str),drop_first=False).astype('int8').columns)
state_dept = list(pd.get_dummies(product.state_id.astype(str) + "_" + product.dept_id.astype(str),drop_first=False).astype('int8').columns)
store_cat = list(pd.get_dummies(product.store_id.astype(str) + "_" + product.cat_id.astype(str),drop_first=False).astype('int8').columns)
store_dept = list(pd.get_dummies(product.store_id.astype(str) + "_" + product.dept_id.astype(str),drop_first=False).astype('int8').columns)
item = list(pd.get_dummies(product.item_id.astype(str),drop_first=False).astype('int8').columns)
state_item = list(pd.get_dummies(product.state_id.astype(str) + "_" + product.item_id.astype(str),drop_first=False).astype('int8').columns)
store_item = list(product["store_item_id"].values)

# %%
for category in [state, store, cat, dept, state_cat, state_dept, store_cat, store_dept, item, state_item, store_item]:
    if category in [state, store, cat, dept, item]:
        X = []
        for word in category:
            X.append(word + "_X")
        index_list = index_list + X
        
    elif category in [state_cat, state_dept, store_cat, store_dept, state_item, store_item]:
        index_list = index_list + category
        
index_list
# Out:
# ['Total_X',
#  'CA_X',
#  'TX_X',
#  'WI_X',
#  'CA_1_X',
#  'CA_2_X',
#  'CA_3_X',
#  'CA_4_X',
#  'TX_1_X',
#  'TX_2_X',
#  'TX_3_X',
#  'WI_1_X',
#  'WI_2_X',
#  'WI_3_X',
#  'FOODS_X',
#  'HOBBIES_X',
#  'HOUSEHOLD_X',
#  'FOODS_1_X',
#  'FOODS_2_X',
#  'FOODS_3_X',
#  'HOBBIES_1_X',
#  'HOBBIES_2_X',
#  'HOUSEHOLD_1_X',
#  'HOUSEHOLD_2_X',
#  'CA_FOODS',
#  'CA_HOBBIES',
#  'CA_HOUSEHOLD',
#  'TX_FOODS',
#  'TX_HOBBIES',
#  'TX_HOUSEHOLD',
#  'WI_FOODS',
#  'WI_HOBBIES',
#  'WI_HOUSEHOLD',
#  'CA_FOODS_1',
#  'CA_FOODS_2',
#  'CA_FOODS_3',
#  'CA_HOBBIES_1',
#  'CA_HOBBIES_2',
#  'CA_HOUSEHOLD_1',
#  'CA_HOUSEHOLD_2',
#  'TX_FOODS_1',
#  'TX_FOODS_2',
#  'TX_FOODS_3',
#  'TX_HOBBIES_1',
#  'TX_HOBBIES_2',
#  'TX_HOUSEHOLD_1',
#  'TX_HOUSEHOLD_2',
#  'WI_FOODS_1',
#  'WI_FOODS_2',
#  'WI_FOODS_3',
#  'WI_HOBBIES_1',
#  'WI_HOBBIES_2',
#  'WI_HOUSEHOLD_1',
#  'WI_HOUSEHOLD_2',
#  'CA_1_FOODS',
#  'CA_1_HOBBIES',
#  'CA_1_HOUSEHOLD',
#  'CA_2_FOODS',
#  'CA_2_HOBBIES',
#  'CA_2_HOUSEHOLD',
#  'CA_3_FOODS',
#  'CA_3_HOBBIES',
#  'CA_3_HOUSEHOLD',
#  'CA_4_FOODS',
#  'CA_4_HOBBIES',
#  'CA_4_HOUSEHOLD',
#  'TX_1_FOODS',
#  'TX_1_HOBBIES',
#  'TX_1_HOUSEHOLD',
#  'TX_2_FOODS',
#  'TX_2_HOBBIES',
#  'TX_2_HOUSEHOLD',
#  'TX_3_FOODS',
#  'TX_3_HOBBIES',
#  'TX_3_HOUSEHOLD',
#  'WI_1_FOODS',
#  'WI_1_HOBBIES',
#  'WI_1_HOUSEHOLD',
#  'WI_2_FOODS',
#  'WI_2_HOBBIES',
#  'WI_2_HOUSEHOLD',
#  'WI_3_FOODS',
#  'WI_3_HOBBIES',
#  'WI_3_HOUSEHOLD',
#  'CA_1_FOODS_1',
#  'CA_1_FOODS_2',
#  'CA_1_FOODS_3',
#  'CA_1_HOBBIES_1',
#  'CA_1_HOBBIES_2',
#  'CA_1_HOUSEHOLD_1',
#  'CA_1_HOUSEHOLD_2',
#  'CA_2_FOODS_1',
#  'CA_2_FOODS_2',
#  'CA_2_FOODS_3',
#  'CA_2_HOBBIES_1',
#  'CA_2_HOBBIES_2',
#  'CA_2_HOUSEHOLD_1',
#  'CA_2_HOUSEHOLD_2',
#  'CA_3_FOODS_1',
#  'CA_3_FOODS_2',
#  'CA_3_FOODS_3',
#  'CA_3_HOBBIES_1',
#  'CA_3_HOBBIES_2',
#  'CA_3_HOUSEHOLD_1',
#  'CA_3_HOUSEHOLD_2',
#  'CA_4_FOODS_1',
#  'CA_4_FOODS_2',
#  'CA_4_FOODS_3',
#  'CA_4_HOBBIES_1',
#  'CA_4_HOBBIES_2',
#  'CA_4_HOUSEHOLD_1',
#  'CA_4_HOUSEHOLD_2',
#  'TX_1_FOODS_1',
#  'TX_1_FOODS_2',
#  'TX_1_FOODS_3',
#  'TX_1_HOBBIES_1',
#  'TX_1_HOBBIES_2',
#  'TX_1_HOUSEHOLD_1',
#  'TX_1_HOUSEHOLD_2',
#  'TX_2_FOODS_1',
#  'TX_2_FOODS_2',
#  'TX_2_FOODS_3',
#  'TX_2_HOBBIES_1',
#  'TX_2_HOBBIES_2',
#  'TX_2_HOUSEHOLD_1',
#  'TX_2_HOUSEHOLD_2',
#  'TX_3_FOODS_1',
#  'TX_3_FOODS_2',
#  'TX_3_FOODS_3',
#  'TX_3_HOBBIES_1',
#  'TX_3_HOBBIES_2',
#  'TX_3_HOUSEHOLD_1',
#  'TX_3_HOUSEHOLD_2',
#  'WI_1_FOODS_1',
#  'WI_1_FOODS_2',
#  'WI_1_FOODS_3',
#  'WI_1_HOBBIES_1',
#  'WI_1_HOBBIES_2',
#  'WI_1_HOUSEHOLD_1',
#  'WI_1_HOUSEHOLD_2',
#  'WI_2_FOODS_1',
#  'WI_2_FOODS_2',
#  'WI_2_FOODS_3',
#  'WI_2_HOBBIES_1',
#  'WI_2_HOBBIES_2',
#  'WI_2_HOUSEHOLD_1',
#  'WI_2_HOUSEHOLD_2',
#  'WI_3_FOODS_1',
#  'WI_3_FOODS_2',
#  'WI_3_FOODS_3',
#  'WI_3_HOBBIES_1',
#  'WI_3_HOBBIES_2',
#  'WI_3_HOUSEHOLD_1',
#  'WI_3_HOUSEHOLD_2',
#  'FOODS_1_001_X',
#  'FOODS_1_002_X',
#  'FOODS_1_003_X',
#  'FOODS_1_004_X',
#  'FOODS_1_005_X',
#  'FOODS_1_006_X',
#  'FOODS_1_008_X',
#  'FOODS_1_009_X',
#  'FOODS_1_010_X',
#  'FOODS_1_011_X',
#  'FOODS_1_012_X',
#  'FOODS_1_013_X',
#  'FOODS_1_014_X',
#  'FOODS_1_015_X',
#  'FOODS_1_016_X',
#  'FOODS_1_017_X',
#  'FOODS_1_018_X',
#  'FOODS_1_019_X',
#  'FOODS_1_020_X',
#  'FOODS_1_021_X',
#  'FOODS_1_022_X',
#  'FOODS_1_023_X',
#  'FOODS_1_024_X',
#  'FOODS_1_025_X',
#  'FOODS_1_026_X',
#  'FOODS_1_027_X',
#  'FOODS_1_028_X',
#  'FOODS_1_029_X',
#  'FOODS_1_030_X',
#  'FOODS_1_031_X',
#  'FOODS_1_032_X',
#  'FOODS_1_033_X',
#  'FOODS_1_034_X',
#  'FOODS_1_035_X',
#  'FOODS_1_036_X',
#  'FOODS_1_037_X',
#  'FOODS_1_038_X',
#  'FOODS_1_039_X',
#  'FOODS_1_040_X',
#  'FOODS_1_041_X',
#  'FOODS_1_042_X',
#  'FOODS_1_043_X',
#  'FOODS_1_044_X',
#  'FOODS_1_045_X',
#  'FOODS_1_046_X',
#  'FOODS_1_047_X',
#  'FOODS_1_048_X',
#  'FOODS_1_049_X',
#  'FOODS_1_050_X',
#  'FOODS_1_051_X',
#  'FOODS_1_052_X',
#  'FOODS_1_053_X',
#  'FOODS_1_054_X',
#  'FOODS_1_055_X',
#  'FOODS_1_056_X',
#  'FOODS_1_057_X',
#  'FOODS_1_058_X',
#  'FOODS_1_059_X',
#  'FOODS_1_060_X',
#  'FOODS_1_061_X',
#  'FOODS_1_062_X',
#  'FOODS_1_063_X',
#  'FOODS_1_064_X',
#  'FOODS_1_065_X',
#  'FOODS_1_066_X',
#  'FOODS_1_067_X',
#  'FOODS_1_068_X',
#  'FOODS_1_069_X',
#  'FOODS_1_070_X',
#  'FOODS_1_071_X',
#  'FOODS_1_072_X',
#  'FOODS_1_073_X',
#  'FOODS_1_074_X',
#  'FOODS_1_075_X',
#  'FOODS_1_076_X',
#  'FOODS_1_077_X',
#  'FOODS_1_078_X',
#  'FOODS_1_079_X',
#  'FOODS_1_080_X',
#  'FOODS_1_081_X',
#  'FOODS_1_082_X',
#  'FOODS_1_083_X',
#  'FOODS_1_084_X',
#  'FOODS_1_085_X',
#  'FOODS_1_086_X',
#  'FOODS_1_087_X',
#  'FOODS_1_088_X',
#  'FOODS_1_089_X',
#  'FOODS_1_090_X',
#  'FOODS_1_091_X',
#  'FOODS_1_092_X',
#  'FOODS_1_093_X',
#  'FOODS_1_094_X',
#  'FOODS_1_095_X',
#  'FOODS_1_096_X',
#  'FOODS_1_097_X',
#  'FOODS_1_098_X',
#  'FOODS_1_099_X',
#  'FOODS_1_101_X',
#  'FOODS_1_102_X',
#  'FOODS_1_103_X',
#  'FOODS_1_104_X',
#  'FOODS_1_105_X',
#  'FOODS_1_106_X',
#  'FOODS_1_107_X',
#  'FOODS_1_108_X',
#  'FOODS_1_109_X',
#  'FOODS_1_110_X',
#  'FOODS_1_111_X',
#  'FOODS_1_112_X',
#  'FOODS_1_113_X',
#  'FOODS_1_114_X',
#  'FOODS_1_115_X',
#  'FOODS_1_116_X',
#  'FOODS_1_117_X',
#  'FOODS_1_118_X',
#  'FOODS_1_119_X',
#  'FOODS_1_120_X',
#  'FOODS_1_121_X',
#  'FOODS_1_122_X',
#  'FOODS_1_123_X',
#  'FOODS_1_124_X',
#  'FOODS_1_125_X',
#  'FOODS_1_126_X',
#  'FOODS_1_127_X',
#  'FOODS_1_128_X',
#  'FOODS_1_129_X',
#  'FOODS_1_130_X',
#  'FOODS_1_131_X',
#  'FOODS_1_132_X',
#  'FOODS_1_133_X',
#  'FOODS_1_134_X',
#  'FOODS_1_135_X',
#  'FOODS_1_136_X',
#  'FOODS_1_137_X',
#  'FOODS_1_138_X',
#  'FOODS_1_139_X',
#  'FOODS_1_140_X',
#  'FOODS_1_141_X',
#  'FOODS_1_142_X',
#  'FOODS_1_143_X',
#  'FOODS_1_144_X',
#  'FOODS_1_145_X',
#  'FOODS_1_146_X',
#  'FOODS_1_147_X',
#  'FOODS_1_148_X',
#  'FOODS_1_149_X',
#  'FOODS_1_150_X',
#  'FOODS_1_151_X',
#  'FOODS_1_152_X',
#  'FOODS_1_153_X',
#  'FOODS_1_154_X',
#  'FOODS_1_155_X',
#  'FOODS_1_156_X',
#  'FOODS_1_157_X',
#  'FOODS_1_158_X',
#  'FOODS_1_159_X',
#  'FOODS_1_160_X',
#  'FOODS_1_161_X',
#  'FOODS_1_162_X',
#  'FOODS_1_163_X',
#  'FOODS_1_164_X',
#  'FOODS_1_166_X',
#  'FOODS_1_167_X',
#  'FOODS_1_168_X',
#  'FOODS_1_169_X',
#  'FOODS_1_170_X',
#  'FOODS_1_171_X',
#  'FOODS_1_172_X',
#  'FOODS_1_173_X',
#  'FOODS_1_174_X',
#  'FOODS_1_175_X',
#  'FOODS_1_176_X',
#  'FOODS_1_177_X',
#  'FOODS_1_178_X',
#  'FOODS_1_179_X',
#  'FOODS_1_180_X',
#  'FOODS_1_181_X',
#  'FOODS_1_182_X',
#  'FOODS_1_183_X',
#  'FOODS_1_184_X',
#  'FOODS_1_185_X',
#  'FOODS_1_186_X',
#  'FOODS_1_187_X',
#  'FOODS_1_188_X',
#  'FOODS_1_189_X',
#  'FOODS_1_190_X',
#  'FOODS_1_191_X',
#  'FOODS_1_192_X',
#  'FOODS_1_193_X',
#  'FOODS_1_194_X',
#  'FOODS_1_195_X',
#  'FOODS_1_196_X',
#  'FOODS_1_197_X',
#  'FOODS_1_198_X',
#  'FOODS_1_199_X',
#  'FOODS_1_200_X',
#  'FOODS_1_201_X',
#  'FOODS_1_202_X',
#  'FOODS_1_203_X',
#  'FOODS_1_204_X',
#  'FOODS_1_205_X',
#  'FOODS_1_206_X',
#  'FOODS_1_207_X',
#  'FOODS_1_208_X',
#  'FOODS_1_209_X',
#  'FOODS_1_210_X',
#  'FOODS_1_211_X',
#  'FOODS_1_212_X',
#  'FOODS_1_213_X',
#  'FOODS_1_214_X',
#  'FOODS_1_215_X',
#  'FOODS_1_216_X',
#  'FOODS_1_217_X',
#  'FOODS_1_218_X',
#  'FOODS_1_219_X',
#  'FOODS_2_001_X',
#  'FOODS_2_002_X',
#  'FOODS_2_003_X',
#  'FOODS_2_004_X',
#  'FOODS_2_005_X',
#  'FOODS_2_006_X',
#  'FOODS_2_007_X',
#  'FOODS_2_008_X',
#  'FOODS_2_009_X',
#  'FOODS_2_010_X',
#  'FOODS_2_011_X',
#  'FOODS_2_012_X',
#  'FOODS_2_013_X',
#  'FOODS_2_014_X',
#  'FOODS_2_015_X',
#  'FOODS_2_016_X',
#  'FOODS_2_017_X',
#  'FOODS_2_018_X',
#  'FOODS_2_019_X',
#  'FOODS_2_020_X',
#  'FOODS_2_021_X',
#  'FOODS_2_022_X',
#  'FOODS_2_023_X',
#  'FOODS_2_024_X',
#  'FOODS_2_025_X',
#  'FOODS_2_026_X',
#  'FOODS_2_027_X',
#  'FOODS_2_028_X',
#  'FOODS_2_029_X',
#  'FOODS_2_030_X',
#  'FOODS_2_031_X',
#  'FOODS_2_032_X',
#  'FOODS_2_033_X',
#  'FOODS_2_034_X',
#  'FOODS_2_035_X',
#  'FOODS_2_036_X',
#  'FOODS_2_037_X',
#  'FOODS_2_038_X',
#  'FOODS_2_039_X',
#  'FOODS_2_040_X',
#  'FOODS_2_041_X',
#  'FOODS_2_042_X',
#  'FOODS_2_043_X',
#  'FOODS_2_044_X',
#  'FOODS_2_045_X',
#  'FOODS_2_046_X',
#  'FOODS_2_047_X',
#  'FOODS_2_048_X',
#  'FOODS_2_049_X',
#  'FOODS_2_050_X',
#  'FOODS_2_051_X',
#  'FOODS_2_052_X',
#  'FOODS_2_053_X',
#  'FOODS_2_054_X',
#  'FOODS_2_055_X',
#  'FOODS_2_056_X',
#  'FOODS_2_057_X',
#  'FOODS_2_058_X',
#  'FOODS_2_059_X',
#  'FOODS_2_060_X',
#  'FOODS_2_061_X',
#  'FOODS_2_062_X',
#  'FOODS_2_063_X',
#  'FOODS_2_064_X',
#  'FOODS_2_065_X',
#  'FOODS_2_066_X',
#  'FOODS_2_067_X',
#  'FOODS_2_068_X',
#  'FOODS_2_069_X',
#  'FOODS_2_070_X',
#  'FOODS_2_071_X',
#  'FOODS_2_072_X',
#  'FOODS_2_073_X',
#  'FOODS_2_074_X',
#  'FOODS_2_075_X',
#  'FOODS_2_076_X',
#  'FOODS_2_077_X',
#  'FOODS_2_078_X',
#  'FOODS_2_079_X',
#  'FOODS_2_080_X',
#  'FOODS_2_081_X',
#  'FOODS_2_082_X',
#  'FOODS_2_083_X',
#  'FOODS_2_084_X',
#  'FOODS_2_085_X',
#  'FOODS_2_086_X',
#  'FOODS_2_087_X',
#  'FOODS_2_088_X',
#  'FOODS_2_089_X',
#  'FOODS_2_090_X',
#  'FOODS_2_091_X',
#  'FOODS_2_092_X',
#  'FOODS_2_093_X',
#  'FOODS_2_094_X',
#  'FOODS_2_095_X',
#  'FOODS_2_096_X',
#  'FOODS_2_097_X',
#  'FOODS_2_099_X',
#  'FOODS_2_100_X',
#  'FOODS_2_101_X',
#  'FOODS_2_102_X',
#  'FOODS_2_103_X',
#  'FOODS_2_104_X',
#  'FOODS_2_105_X',
#  'FOODS_2_106_X',
#  'FOODS_2_107_X',
#  'FOODS_2_108_X',
#  'FOODS_2_109_X',
#  'FOODS_2_110_X',
#  'FOODS_2_111_X',
#  'FOODS_2_112_X',
#  'FOODS_2_113_X',
#  'FOODS_2_114_X',
#  'FOODS_2_115_X',
#  'FOODS_2_116_X',
#  'FOODS_2_117_X',
#  'FOODS_2_118_X',
#  'FOODS_2_119_X',
#  'FOODS_2_120_X',
#  'FOODS_2_121_X',
#  'FOODS_2_122_X',
#  'FOODS_2_123_X',
#  'FOODS_2_124_X',
#  'FOODS_2_125_X',
#  'FOODS_2_126_X',
#  'FOODS_2_127_X',
#  'FOODS_2_128_X',
#  'FOODS_2_129_X',
#  'FOODS_2_130_X',
#  'FOODS_2_131_X',
#  'FOODS_2_132_X',
#  'FOODS_2_133_X',
#  'FOODS_2_134_X',
#  'FOODS_2_135_X',
#  'FOODS_2_136_X',
#  'FOODS_2_137_X',
#  'FOODS_2_138_X',
#  'FOODS_2_139_X',
#  'FOODS_2_140_X',
#  'FOODS_2_141_X',
#  'FOODS_2_142_X',
#  'FOODS_2_143_X',
#  'FOODS_2_144_X',
#  'FOODS_2_145_X',
#  'FOODS_2_146_X',
#  'FOODS_2_147_X',
#  'FOODS_2_148_X',
#  'FOODS_2_149_X',
#  'FOODS_2_150_X',
#  'FOODS_2_151_X',
#  'FOODS_2_152_X',
#  'FOODS_2_153_X',
#  'FOODS_2_154_X',
#  'FOODS_2_155_X',
#  'FOODS_2_156_X',
#  'FOODS_2_157_X',
#  'FOODS_2_158_X',
#  'FOODS_2_159_X',
#  'FOODS_2_160_X',
#  'FOODS_2_161_X',
#  'FOODS_2_162_X',
#  'FOODS_2_163_X',
#  'FOODS_2_164_X',
#  'FOODS_2_165_X',
#  'FOODS_2_166_X',
#  'FOODS_2_167_X',
#  'FOODS_2_168_X',
#  'FOODS_2_169_X',
#  'FOODS_2_170_X',
#  'FOODS_2_171_X',
#  'FOODS_2_172_X',
#  'FOODS_2_173_X',
#  'FOODS_2_174_X',
#  'FOODS_2_175_X',
#  'FOODS_2_176_X',
#  'FOODS_2_177_X',
#  'FOODS_2_178_X',
#  'FOODS_2_179_X',
#  'FOODS_2_180_X',
#  'FOODS_2_181_X',
#  'FOODS_2_182_X',
#  'FOODS_2_183_X',
#  'FOODS_2_184_X',
#  'FOODS_2_185_X',
#  'FOODS_2_186_X',
#  'FOODS_2_187_X',
#  'FOODS_2_188_X',
#  'FOODS_2_189_X',
#  'FOODS_2_190_X',
#  'FOODS_2_191_X',
#  'FOODS_2_192_X',
#  'FOODS_2_193_X',
#  'FOODS_2_194_X',
#  'FOODS_2_195_X',
#  'FOODS_2_196_X',
#  'FOODS_2_197_X',
#  'FOODS_2_198_X',
#  'FOODS_2_199_X',
#  'FOODS_2_200_X',
#  'FOODS_2_201_X',
#  'FOODS_2_202_X',
#  'FOODS_2_203_X',
#  'FOODS_2_204_X',
#  'FOODS_2_205_X',
#  'FOODS_2_206_X',
#  'FOODS_2_207_X',
#  'FOODS_2_208_X',
#  'FOODS_2_209_X',
#  'FOODS_2_210_X',
#  'FOODS_2_211_X',
#  'FOODS_2_212_X',
#  'FOODS_2_213_X',
#  'FOODS_2_214_X',
#  'FOODS_2_215_X',
#  'FOODS_2_216_X',
#  'FOODS_2_217_X',
#  'FOODS_2_218_X',
#  'FOODS_2_219_X',
#  'FOODS_2_220_X',
#  'FOODS_2_221_X',
#  'FOODS_2_222_X',
#  'FOODS_2_223_X',
#  'FOODS_2_224_X',
#  'FOODS_2_225_X',
#  'FOODS_2_226_X',
#  'FOODS_2_227_X',
#  'FOODS_2_228_X',
#  'FOODS_2_229_X',
#  'FOODS_2_230_X',
#  'FOODS_2_231_X',
#  'FOODS_2_232_X',
#  'FOODS_2_233_X',
#  'FOODS_2_234_X',
#  'FOODS_2_235_X',
#  'FOODS_2_236_X',
#  'FOODS_2_237_X',
#  'FOODS_2_238_X',
#  'FOODS_2_239_X',
#  'FOODS_2_240_X',
#  'FOODS_2_241_X',
#  'FOODS_2_242_X',
#  'FOODS_2_243_X',
#  'FOODS_2_244_X',
#  'FOODS_2_245_X',
#  'FOODS_2_246_X',
#  'FOODS_2_247_X',
#  'FOODS_2_248_X',
#  'FOODS_2_249_X',
#  'FOODS_2_250_X',
#  'FOODS_2_251_X',
#  'FOODS_2_252_X',
#  'FOODS_2_253_X',
#  'FOODS_2_254_X',
#  'FOODS_2_255_X',
#  'FOODS_2_256_X',
#  'FOODS_2_257_X',
#  'FOODS_2_258_X',
#  'FOODS_2_259_X',
#  'FOODS_2_260_X',
#  'FOODS_2_261_X',
#  'FOODS_2_262_X',
#  'FOODS_2_263_X',
#  'FOODS_2_264_X',
#  'FOODS_2_265_X',
#  'FOODS_2_266_X',
#  'FOODS_2_267_X',
#  'FOODS_2_268_X',
#  'FOODS_2_269_X',
#  'FOODS_2_270_X',
#  'FOODS_2_271_X',
#  'FOODS_2_272_X',
#  'FOODS_2_273_X',
#  'FOODS_2_274_X',
#  'FOODS_2_275_X',
#  'FOODS_2_276_X',
#  'FOODS_2_277_X',
#  'FOODS_2_278_X',
#  'FOODS_2_279_X',
#  'FOODS_2_280_X',
#  'FOODS_2_281_X',
#  'FOODS_2_282_X',
#  'FOODS_2_283_X',
#  'FOODS_2_284_X',
#  'FOODS_2_285_X',
#  'FOODS_2_286_X',
#  'FOODS_2_287_X',
#  'FOODS_2_288_X',
#  'FOODS_2_289_X',
#  'FOODS_2_290_X',
#  'FOODS_2_291_X',
#  'FOODS_2_292_X',
#  'FOODS_2_293_X',
#  'FOODS_2_294_X',
#  'FOODS_2_295_X',
#  'FOODS_2_296_X',
#  'FOODS_2_297_X',
#  'FOODS_2_298_X',
#  'FOODS_2_299_X',
#  'FOODS_2_300_X',
#  'FOODS_2_301_X',
#  'FOODS_2_302_X',
#  'FOODS_2_303_X',
#  'FOODS_2_304_X',
#  'FOODS_2_305_X',
#  'FOODS_2_306_X',
#  'FOODS_2_307_X',
#  'FOODS_2_308_X',
#  'FOODS_2_309_X',
#  'FOODS_2_310_X',
#  'FOODS_2_311_X',
#  'FOODS_2_312_X',
#  'FOODS_2_313_X',
#  'FOODS_2_314_X',
#  'FOODS_2_315_X',
#  'FOODS_2_316_X',
#  'FOODS_2_317_X',
#  'FOODS_2_318_X',
#  'FOODS_2_319_X',
#  'FOODS_2_320_X',
#  'FOODS_2_321_X',
#  'FOODS_2_322_X',
#  'FOODS_2_323_X',
#  'FOODS_2_324_X',
#  'FOODS_2_325_X',
#  'FOODS_2_326_X',
#  'FOODS_2_327_X',
#  'FOODS_2_328_X',
#  'FOODS_2_329_X',
#  'FOODS_2_330_X',
#  'FOODS_2_331_X',
#  'FOODS_2_332_X',
#  'FOODS_2_333_X',
#  'FOODS_2_334_X',
#  'FOODS_2_335_X',
#  'FOODS_2_336_X',
#  'FOODS_2_337_X',
#  'FOODS_2_338_X',
#  'FOODS_2_339_X',
#  'FOODS_2_340_X',
#  'FOODS_2_341_X',
#  'FOODS_2_342_X',
#  'FOODS_2_343_X',
#  'FOODS_2_344_X',
#  'FOODS_2_345_X',
#  'FOODS_2_346_X',
#  'FOODS_2_347_X',
#  'FOODS_2_348_X',
#  'FOODS_2_349_X',
#  'FOODS_2_350_X',
#  'FOODS_2_351_X',
#  'FOODS_2_352_X',
#  'FOODS_2_353_X',
#  'FOODS_2_354_X',
#  'FOODS_2_355_X',
#  'FOODS_2_356_X',
#  'FOODS_2_357_X',
#  'FOODS_2_358_X',
#  'FOODS_2_359_X',
#  'FOODS_2_360_X',
#  'FOODS_2_361_X',
#  'FOODS_2_362_X',
#  'FOODS_2_363_X',
#  'FOODS_2_364_X',
#  'FOODS_2_365_X',
#  'FOODS_2_366_X',
#  'FOODS_2_367_X',
#  'FOODS_2_368_X',
#  'FOODS_2_369_X',
#  'FOODS_2_370_X',
#  'FOODS_2_371_X',
#  'FOODS_2_372_X',
#  'FOODS_2_373_X',
#  'FOODS_2_374_X',
#  'FOODS_2_375_X',
#  'FOODS_2_376_X',
#  'FOODS_2_377_X',
#  'FOODS_2_378_X',
#  'FOODS_2_379_X',
#  'FOODS_2_380_X',
#  'FOODS_2_381_X',
#  'FOODS_2_382_X',
#  'FOODS_2_383_X',
#  'FOODS_2_384_X',
#  'FOODS_2_385_X',
#  'FOODS_2_386_X',
#  'FOODS_2_387_X',
#  'FOODS_2_388_X',
#  'FOODS_2_389_X',
#  'FOODS_2_390_X',
#  'FOODS_2_391_X',
#  'FOODS_2_392_X',
#  'FOODS_2_393_X',
#  'FOODS_2_394_X',
#  'FOODS_2_395_X',
#  'FOODS_2_396_X',
#  'FOODS_2_397_X',
#  'FOODS_2_398_X',
#  'FOODS_2_399_X',
#  'FOODS_3_001_X',
#  'FOODS_3_002_X',
#  'FOODS_3_003_X',
#  'FOODS_3_004_X',
#  'FOODS_3_005_X',
#  'FOODS_3_006_X',
#  'FOODS_3_007_X',
#  'FOODS_3_008_X',
#  'FOODS_3_009_X',
#  'FOODS_3_010_X',
#  'FOODS_3_011_X',
#  'FOODS_3_012_X',
#  'FOODS_3_013_X',
#  'FOODS_3_014_X',
#  'FOODS_3_015_X',
#  'FOODS_3_016_X',
#  'FOODS_3_017_X',
#  'FOODS_3_018_X',
#  'FOODS_3_019_X',
#  'FOODS_3_020_X',
#  'FOODS_3_021_X',
#  'FOODS_3_022_X',
#  'FOODS_3_023_X',
#  'FOODS_3_024_X',
#  'FOODS_3_025_X',
#  'FOODS_3_026_X',
#  'FOODS_3_027_X',
#  'FOODS_3_028_X',
#  'FOODS_3_029_X',
#  'FOODS_3_030_X',
#  'FOODS_3_031_X',
#  'FOODS_3_032_X',
#  'FOODS_3_033_X',
#  'FOODS_3_034_X',
#  'FOODS_3_035_X',
#  'FOODS_3_036_X',
#  'FOODS_3_037_X',
#  'FOODS_3_038_X',
#  'FOODS_3_039_X',
#  'FOODS_3_040_X',
#  'FOODS_3_041_X',
#  'FOODS_3_042_X',
#  'FOODS_3_043_X',
#  'FOODS_3_044_X',
#  'FOODS_3_045_X',
#  'FOODS_3_046_X',
#  'FOODS_3_047_X',
#  'FOODS_3_048_X',
#  'FOODS_3_049_X',
#  'FOODS_3_050_X',
#  'FOODS_3_051_X',
#  'FOODS_3_053_X',
#  'FOODS_3_054_X',
#  'FOODS_3_055_X',
#  'FOODS_3_056_X',
#  'FOODS_3_057_X',
#  'FOODS_3_058_X',
#  'FOODS_3_059_X',
#  'FOODS_3_060_X',
#  'FOODS_3_061_X',
#  'FOODS_3_062_X',
#  'FOODS_3_063_X',
#  'FOODS_3_064_X',
#  'FOODS_3_065_X',
#  'FOODS_3_066_X',
#  'FOODS_3_067_X',
#  'FOODS_3_068_X',
#  'FOODS_3_069_X',
#  'FOODS_3_070_X',
#  'FOODS_3_071_X',
#  'FOODS_3_072_X',
#  'FOODS_3_073_X',
#  'FOODS_3_074_X',
#  'FOODS_3_075_X',
#  'FOODS_3_076_X',
#  'FOODS_3_077_X',
#  'FOODS_3_078_X',
#  'FOODS_3_079_X',
#  'FOODS_3_080_X',
#  'FOODS_3_081_X',
#  'FOODS_3_082_X',
#  'FOODS_3_083_X',
#  'FOODS_3_084_X',
#  'FOODS_3_085_X',
#  'FOODS_3_086_X',
#  'FOODS_3_087_X',
#  'FOODS_3_088_X',
#  'FOODS_3_089_X',
#  'FOODS_3_090_X',
#  'FOODS_3_091_X',
#  'FOODS_3_092_X',
#  'FOODS_3_093_X',
#  'FOODS_3_094_X',
#  'FOODS_3_095_X',
#  'FOODS_3_096_X',
#  'FOODS_3_097_X',
#  'FOODS_3_098_X',
#  'FOODS_3_099_X',
#  'FOODS_3_100_X',
#  'FOODS_3_101_X',
#  'FOODS_3_102_X',
#  'FOODS_3_103_X',
#  'FOODS_3_104_X',
#  'FOODS_3_105_X',
#  'FOODS_3_106_X',
#  'FOODS_3_107_X',
#  'FOODS_3_108_X',
#  'FOODS_3_109_X',
#  'FOODS_3_110_X',
#  'FOODS_3_111_X',
#  'FOODS_3_112_X',
#  'FOODS_3_113_X',
#  'FOODS_3_114_X',
#  'FOODS_3_115_X',
#  'FOODS_3_116_X',
#  'FOODS_3_117_X',
#  'FOODS_3_118_X',
#  'FOODS_3_119_X',
#  'FOODS_3_120_X',
#  'FOODS_3_121_X',
#  'FOODS_3_122_X',
#  'FOODS_3_123_X',
#  'FOODS_3_124_X',
#  'FOODS_3_125_X',
#  'FOODS_3_126_X',
#  'FOODS_3_127_X',
#  'FOODS_3_128_X',
#  'FOODS_3_129_X',
#  'FOODS_3_130_X',
#  'FOODS_3_131_X',
#  'FOODS_3_132_X',
#  'FOODS_3_133_X',
#  'FOODS_3_134_X',
#  'FOODS_3_135_X',
#  'FOODS_3_136_X',
#  'FOODS_3_137_X',
#  'FOODS_3_138_X',
#  'FOODS_3_139_X',
#  'FOODS_3_140_X',
#  'FOODS_3_141_X',
#  'FOODS_3_142_X',
#  'FOODS_3_143_X',
#  'FOODS_3_144_X',
#  'FOODS_3_145_X',
#  'FOODS_3_146_X',
#  'FOODS_3_147_X',
#  'FOODS_3_148_X',
#  'FOODS_3_149_X',
#  'FOODS_3_150_X',
#  'FOODS_3_151_X',
#  'FOODS_3_152_X',
#  'FOODS_3_153_X',
#  'FOODS_3_154_X',
#  'FOODS_3_155_X',
#  'FOODS_3_156_X',
#  'FOODS_3_157_X',
#  'FOODS_3_158_X',
#  'FOODS_3_159_X',
#  'FOODS_3_160_X',
#  'FOODS_3_161_X',
#  'FOODS_3_162_X',
#  'FOODS_3_163_X',
#  'FOODS_3_164_X',
#  'FOODS_3_165_X',
#  'FOODS_3_166_X',
#  'FOODS_3_167_X',
#  'FOODS_3_168_X',
#  'FOODS_3_169_X',
#  'FOODS_3_170_X',
#  'FOODS_3_171_X',
#  'FOODS_3_172_X',
#  'FOODS_3_173_X',
#  'FOODS_3_174_X',
#  'FOODS_3_175_X',
#  'FOODS_3_176_X',
#  'FOODS_3_177_X',
#  'FOODS_3_178_X',
#  'FOODS_3_179_X',
#  'FOODS_3_180_X',
#  'FOODS_3_181_X',
#  'FOODS_3_182_X',
#  'FOODS_3_183_X',
#  'FOODS_3_184_X',
#  'FOODS_3_185_X',
#  'FOODS_3_186_X',
#  'FOODS_3_187_X',
#  'FOODS_3_188_X',
#  'FOODS_3_189_X',
#  'FOODS_3_190_X',
#  'FOODS_3_191_X',
#  'FOODS_3_192_X',
#  'FOODS_3_193_X',
#  'FOODS_3_194_X',
#  'FOODS_3_195_X',
#  'FOODS_3_196_X',
#  'FOODS_3_197_X',
#  'FOODS_3_198_X',
#  'FOODS_3_199_X',
#  'FOODS_3_200_X',
#  'FOODS_3_201_X',
#  'FOODS_3_202_X',
#  'FOODS_3_203_X',
#  'FOODS_3_204_X',
#  'FOODS_3_205_X',
#  'FOODS_3_206_X',
#  'FOODS_3_207_X',
#  'FOODS_3_208_X',
#  'FOODS_3_209_X',
#  'FOODS_3_210_X',
#  'FOODS_3_211_X',
#  'FOODS_3_212_X',
#  'FOODS_3_213_X',
#  'FOODS_3_214_X',
#  'FOODS_3_215_X',
#  'FOODS_3_216_X',
#  'FOODS_3_217_X',
#  'FOODS_3_218_X',
#  'FOODS_3_219_X',
#  'FOODS_3_220_X',
#  'FOODS_3_221_X',
#  'FOODS_3_222_X',
#  'FOODS_3_223_X',
#  'FOODS_3_224_X',
#  'FOODS_3_225_X',
#  'FOODS_3_226_X',
#  'FOODS_3_227_X',
#  'FOODS_3_228_X',
#  'FOODS_3_229_X',
#  'FOODS_3_230_X',
#  'FOODS_3_231_X',
#  'FOODS_3_232_X',
#  'FOODS_3_233_X',
#  ...]

# %%
file_list = {"shift1":["public_pred_shift1.pkl", "validation_pred_shift1.pkl", "semival_pred_shift1.pkl"],
             "shift7":["public_pred_shift7.pkl", "validation_pred_shift7.pkl", "semival_pred_shift7.pkl"],
             "shift14":["public_pred_shift14.pkl", "validation_pred_shift14.pkl", "semival_pred_shift14.pkl"],
             "shift21":["public_pred_shift21.pkl", "validation_pred_shift21.pkl", "semival_pred_shift21.pkl"],
             "shift28":["public_pred_shift28.pkl", "validation_pred_shift28.pkl", "semival_pred_shift28.pkl"]}

# %%
aaa = pd.read_pickle(f"prediction/public_pred_shift1.pkl")

# %%
aaa
# Out:
#                                      id store_id  d_serial  \
# 58327370  HOBBIES_1_001_CA_1_evaluation     CA_1      1914
# 58327371  HOBBIES_1_002_CA_1_evaluation     CA_1      1914
# 58327372  HOBBIES_1_003_CA_1_evaluation     CA_1      1914
# 58327373  HOBBIES_1_004_CA_1_evaluation     CA_1      1914
# 58327374  HOBBIES_1_005_CA_1_evaluation     CA_1      1914
# ...                                 ...      ...       ...
# 59181085    FOODS_3_823_WI_3_evaluation     WI_3      1941
# 59181086    FOODS_3_824_WI_3_evaluation     WI_3      1941
# 59181087    FOODS_3_825_WI_3_evaluation     WI_3      1941
# 59181088    FOODS_3_826_WI_3_evaluation     WI_3      1941
# 59181089    FOODS_3_827_WI_3_evaluation     WI_3      1941
#
#           shift_28_rolling_365    target total_id      pred
# 58327370              0.660156 -0.660156    total -0.005046
# 58327371              0.356201 -0.356201    total -0.123840
# 58327372              0.501465 -0.501465    total -0.102393
# 58327373              2.013672 -2.013672    total -0.631070
# 58327374              1.112305 -0.112305    total -0.018369
# ...                        ...       ...      ...       ...
# 59181085              0.581055  0.418945    total  0.112684
# 59181086              0.024658 -0.024658    total  0.168074
# 59181087              0.635742  1.364258    total -0.041877
# 59181088              1.082031 -1.082031    total  0.122735
# 59181089              1.723633 -0.723633    total  0.911924
#
# [853720 rows x 7 columns]

# %%
for shift, file_names in file_list.items():
    pred_shift = pd.DataFrame()
    i = 0
    for file_path in file_names:
        df = pd.read_pickle(f"prediction/{file_path}")
        df["id_serial"] = np.tile(range(30490), 28)
        df["diff"] = df["pred"] - df["target"]
        df = df.pivot_table(index=["id_serial", "id"], columns="d_serial", values="diff", aggfunc=np.sum)
        df = np.dot(cf.values, df.values)
        if i==0:
            pred_shift = df
        else:
            pred_shift = np.concatenate([pred_shift, df], axis=1)
        i+=1

    pred_shift = np.concatenate([pred_shift, np.zeros((42840, 1))], axis=1)
    pred_shift = np.sort(np.abs(pred_shift), axis=1)
    pred_shift = pd.DataFrame(pred_shift, index=index_list, columns=range(28*3+1))
    pred_shift.to_pickle(f"accuracy_pred_shift_summary/{shift}.pkl")

# %%
qs_dict = {0.005: 84,
           0.025: 80,
           0.165: 56,
           0.250: 42,}

# %%
submission = pd.read_csv("Accuracy_private_submit_data/submission_private_1_2_blend.csv") ###### submissionの並び順に気を付ける
submission = submission.iloc[:30490, :]
submission = submission.drop("id", axis=1)
print("行列計算")
submission = np.dot(cf.values, submission.values)
day_cols = [f"F{i}" for i in range(1, 29)]
index_list_modi = []
for word in index_list:
    index_list_modi.append(word + "_0.500_evaluation")
sample_df = pd.DataFrame(submission, index=index_list_modi, columns=day_cols)
display(sample_df)
# result_df = pd.DataFrame()

for i in range(28):
    print(f"START_day{i+1}")
    if 0<= i <= 3:
        pred_shift = pd.read_pickle("accuracy_pred_shift_summary/shift1.pkl")
    elif 4 <= i <= 10:
        pred_shift = pd.read_pickle("accuracy_pred_shift_summary/shift7.pkl")
    elif 11 <= i <= 17:
        pred_shift = pd.read_pickle("accuracy_pred_shift_summary/shift14.pkl")
    elif 18 <= i <= 24:
        pred_shift = pd.read_pickle("accuracy_pred_shift_summary/shift21.pkl")
    elif 25 <= i <= 27:
        pred_shift = pd.read_pickle("accuracy_pred_shift_summary/shift28.pkl")
    
    for point, col in qs_dict.items():
        
        under_name = []
        for word in pred_shift.index:
            under_name.append(word + "_" + "{:.3f}".format(point) + "_evaluation")
            
        over_name = []
        for word in pred_shift.index:
            over_name.append(word + "_" + "{:.3f}".format(1 - point) + "_evaluation")
            
        under = sample_df.iloc[:, i].values - pred_shift.loc[:, col].values
        over = sample_df.iloc[:, i].values + pred_shift.loc[:, col].values
        under_df = pd.DataFrame(under, index=under_name, columns=[f"F{i+1}"])
        over_df = pd.DataFrame(over, index=over_name, columns=[f"F{i+1}"])
        qs_df = pd.concat((under_df, over_df), axis=0)
        if point == 0.005:
            day_pred = qs_df
        else:
            day_pred = pd.concat((day_pred, qs_df), axis=0)
    if i == 0:
        result_df = day_pred
    else:
        result_df = pd.concat((result_df, day_pred), axis=1)
                         
result_df = pd.concat((result_df, sample_df), axis=0)
result_df.iloc[:, :] = np.where(result_df<0, 0, result_df)
# Out:
# 行列計算
#                                              F1            F2            F3  \
# Total_X_0.500_evaluation           41137.592412  37479.769392  36058.595101
# CA_X_0.500_evaluation              18185.809968  16198.216110  15640.121184
# TX_X_0.500_evaluation              11497.268522  10279.533570   9819.049418
# WI_X_0.500_evaluation              11454.513923  11002.019712  10599.424498
# CA_1_X_0.500_evaluation             4657.128448   3983.497045   3796.286637
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.635028      0.499664      0.530591
# FOODS_3_824_WI_3_0.500_evaluation      0.280852      0.235459      0.128940
# FOODS_3_825_WI_3_0.500_evaluation      0.863501      0.610810      0.568233
# FOODS_3_826_WI_3_0.500_evaluation      0.975658      0.966419      0.795826
# FOODS_3_827_WI_3_0.500_evaluation      2.013278      1.512673      1.237191
#
#                                              F4            F5            F6  \
# Total_X_0.500_evaluation           37693.734491  41203.806032  49614.609903
# CA_X_0.500_evaluation              16556.493977  17709.019212  21940.675913
# TX_X_0.500_evaluation              10216.699166  10941.282293  13070.525991
# WI_X_0.500_evaluation              10920.541349  12553.504527  14603.407999
# CA_1_X_0.500_evaluation             4139.184530   4523.327534   5774.384751
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.426002      0.479308      0.619463
# FOODS_3_824_WI_3_0.500_evaluation      0.294478      0.253735      0.110539
# FOODS_3_825_WI_3_0.500_evaluation      0.427312      0.413654      0.646041
# FOODS_3_826_WI_3_0.500_evaluation      0.934104      1.056750      1.287608
# FOODS_3_827_WI_3_0.500_evaluation      1.366653      1.666988      1.717212
#
#                                              F7            F8            F9  \
# Total_X_0.500_evaluation           50033.651407  42173.737449  39527.829175
# CA_X_0.500_evaluation              22549.959930  19549.993269  16928.547206
# TX_X_0.500_evaluation              13423.589768  11067.577268  10447.460138
# WI_X_0.500_evaluation              14060.101709  11556.166913  12151.821832
# CA_1_X_0.500_evaluation             5874.694681   4784.237740   4229.529737
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.683613      0.470341      0.508771
# FOODS_3_824_WI_3_0.500_evaluation      0.171300      0.192541      0.068406
# FOODS_3_825_WI_3_0.500_evaluation      0.741648      0.575655      0.364707
# FOODS_3_826_WI_3_0.500_evaluation      2.024082      1.364649      1.515600
# FOODS_3_827_WI_3_0.500_evaluation      1.931036      1.349888      2.237867
#
#                                             F10  ...           F19  \
# Total_X_0.500_evaluation           41409.207167  ...  45546.922569
# CA_X_0.500_evaluation              17572.002546  ...  19881.178097
# TX_X_0.500_evaluation              11607.073324  ...  11564.923653
# WI_X_0.500_evaluation              12230.131296  ...  14100.820819
# CA_1_X_0.500_evaluation             4399.661977  ...   5139.014179
# ...                                         ...  ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.373604  ...      0.783713
# FOODS_3_824_WI_3_0.500_evaluation      0.248837  ...      0.270310
# FOODS_3_825_WI_3_0.500_evaluation      0.415849  ...      0.771811
# FOODS_3_826_WI_3_0.500_evaluation      0.908024  ...      1.328519
# FOODS_3_827_WI_3_0.500_evaluation      0.944548  ...      1.297524
#
#                                             F20           F21           F22  \
# Total_X_0.500_evaluation           55639.787346  56652.616386  43932.322342
# CA_X_0.500_evaluation              23688.671036  24263.090141  18812.348430
# TX_X_0.500_evaluation              14325.151000  15026.483523  12497.904623
# WI_X_0.500_evaluation              17625.965309  17363.042722  12622.069288
# CA_1_X_0.500_evaluation             6124.161700   6254.431254   4675.912769
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.785924      0.781287      0.685541
# FOODS_3_824_WI_3_0.500_evaluation      0.358676      0.399952      0.212235
# FOODS_3_825_WI_3_0.500_evaluation      1.371575      1.400288      1.156939
# FOODS_3_826_WI_3_0.500_evaluation      1.583570      1.930864      0.947945
# FOODS_3_827_WI_3_0.500_evaluation      2.191924      2.444135      1.084198
#
#                                             F23           F24           F25  \
# Total_X_0.500_evaluation           41392.790328  42817.671865  40385.739396
# CA_X_0.500_evaluation              17124.243475  17068.691437  17047.503207
# TX_X_0.500_evaluation              10682.168954  11600.587125  10741.144224
# WI_X_0.500_evaluation              13586.377900  14148.393304  12597.091965
# CA_1_X_0.500_evaluation             4083.631698   4050.430325   4118.653904
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.410109      0.499516      0.762335
# FOODS_3_824_WI_3_0.500_evaluation      0.294721      0.579474      0.325390
# FOODS_3_825_WI_3_0.500_evaluation      1.036485      1.477602      0.913776
# FOODS_3_826_WI_3_0.500_evaluation      1.496042      1.305131      0.837305
# FOODS_3_827_WI_3_0.500_evaluation      1.082687      1.402743      1.123976
#
#                                             F26           F27           F28
# Total_X_0.500_evaluation           44101.310493  52557.042180  50857.963820
# CA_X_0.500_evaluation              18843.743732  23436.454306  22976.525212
# TX_X_0.500_evaluation              11576.621311  13612.328123  13464.712249
# WI_X_0.500_evaluation              13680.945449  15508.259751  14416.726360
# CA_1_X_0.500_evaluation             4823.917620   6088.100954   6116.942740
# ...                                         ...           ...           ...
# FOODS_3_823_WI_3_0.500_evaluation      0.527647      0.662072      0.641291
# FOODS_3_824_WI_3_0.500_evaluation      0.282897      0.242312      0.357719
# FOODS_3_825_WI_3_0.500_evaluation      0.916823      1.013319      0.675340
# FOODS_3_826_WI_3_0.500_evaluation      0.916730      1.229895      1.365096
# FOODS_3_827_WI_3_0.500_evaluation      1.964650      2.479981      1.608560
#
# [42840 rows x 28 columns]
# START_day1
# START_day2
# START_day3
# START_day4
# START_day5
# START_day6
# START_day7
# START_day8
# START_day9
# START_day10
# START_day11
# START_day12
# START_day13
# START_day14
# START_day15
# START_day16
# START_day17
# START_day18
# START_day19
# START_day20
# START_day21
# START_day22
# START_day23
# START_day24
# START_day25
# START_day26
# START_day27
# START_day28

# %%
submission_no = 1
pred_1_sub = result_df.reset_index()
cols = ["id"] +  [f"F{i}" for i in range(1, 29)]
pred_1_sub.columns = cols
eval_pred = pred_1_sub.copy()
eval_pred["id"] = eval_pred["id"].apply(lambda x: x.replace("evaluation", "validation"))
submission = pd.concat((pred_1_sub, eval_pred), axis=0)
submission.to_csv(f'uncertainty_submission/uncert_submission_private_{submission_no}.csv', index = False)

# %%
submission
# Out:
#                                        id            F1            F2  \
# 0                Total_X_0.005_evaluation  33275.859120  29618.036100
# 1                   CA_X_0.005_evaluation  15170.906904  13183.313046
# 2                   TX_X_0.005_evaluation   9203.260128   7985.525176
# 3                   WI_X_0.005_evaluation   8316.514061   7864.019851
# 4                 CA_1_X_0.005_evaluation   3673.896821   3000.265418
# ...                                   ...           ...           ...
# 385555  FOODS_3_823_WI_3_0.500_validation      0.635028      0.499664
# 385556  FOODS_3_824_WI_3_0.500_validation      0.280852      0.235459
# 385557  FOODS_3_825_WI_3_0.500_validation      0.863501      0.610810
# 385558  FOODS_3_826_WI_3_0.500_validation      0.975658      0.966419
# 385559  FOODS_3_827_WI_3_0.500_validation      2.013278      1.512673
#
#                   F3            F4            F5            F6            F7  \
# 0       28196.861809  29832.001199  33467.431068  41878.234939  42297.276443
# 1       12625.218120  13541.590913  14829.641171  19061.297872  19670.581889
# 2        7525.041024   7922.690772   8777.320048  10906.563747  11259.627523
# 3        7461.424636   7782.541487   9500.656433  11550.559904  11007.253614
# 4        2813.055010   3155.952902   3748.411592   4999.468810   5099.778739
# ...              ...           ...           ...           ...           ...
# 385555      0.530591      0.426002      0.479308      0.619463      0.683613
# 385556      0.128940      0.294478      0.253735      0.110539      0.171300
# 385557      0.568233      0.427312      0.413654      0.646041      0.741648
# 385558      0.795826      0.934104      1.056750      1.287608      2.024082
# 385559      1.237191      1.366653      1.666988      1.717212      1.931036
#
#                   F8            F9  ...           F19           F20  \
# 0       34437.362485  31791.454211  ...  38287.337251  48380.202027
# 1       16670.615228  14049.169164  ...  16969.585977  20777.078915
# 2        8903.615023   8283.497894  ...   9471.267351  12231.494698
# 3        8503.318818   9098.973737  ...  11302.504784  14827.649274
# 4        4009.321798   3454.613796  ...   4338.094785   5323.242306
# ...              ...           ...  ...           ...           ...
# 385555      0.470341      0.508771  ...      0.783713      0.785924
# 385556      0.192541      0.068406  ...      0.270310      0.358676
# 385557      0.575655      0.364707  ...      0.771811      1.371575
# 385558      1.364649      1.515600  ...      1.328519      1.583570
# 385559      1.349888      2.237867  ...      1.297524      2.191924
#
#                  F21           F22           F23           F24           F25  \
# 0       49393.031067  36672.737024  34133.205010  35558.086547  33126.154078
# 1       21351.498021  15900.756310  14212.651354  14157.099316  14135.911087
# 2       12932.827221  10404.248321   8588.512652   9506.930823   8647.487922
# 3       14564.726687   9823.753253  10788.061864  11350.077268   9798.775930
# 4        5453.511860   3874.993375   3282.712304   3249.510932   3317.734510
# ...              ...           ...           ...           ...           ...
# 385555      0.781287      0.685541      0.410109      0.499516      0.762335
# 385556      0.399952      0.212235      0.294721      0.579474      0.325390
# 385557      1.400288      1.156939      1.036485      1.477602      0.913776
# 385558      1.930864      0.947945      1.496042      1.305131      0.837305
# 385559      2.444135      1.084198      1.082687      1.402743      1.123976
#
#                  F26           F27           F28
# 0       37200.395534  45656.127221  43957.048861
# 1       15922.655251  20515.365825  20055.436731
# 2        9539.950404  11575.657216  11428.041342
# 3       10968.264276  12795.578578  11704.045187
# 4        4116.127830   5380.311165   5409.152950
# ...              ...           ...           ...
# 385555      0.527647      0.662072      0.641291
# 385556      0.282897      0.242312      0.357719
# 385557      0.916823      1.013319      0.675340
# 385558      0.916730      1.229895      1.365096
# 385559      1.964650      2.479981      1.608560
#
# [771120 rows x 29 columns]
